# %%
#import
import pandas as pd
import numpy as np
import os
from datetime import datetime

# %%
df_exercises = pd.read_pickle('df_exercises.pickle')

# %%
df_exercises = df_exercises.drop(['cardioWorkload', 'perceivedWorkload' ],axis = 1)

# %%
df_exercises = df_exercises.dropna(how='any')

# %%
df_exercises = df_exercises[~(df_exercises == 0).any(axis=1)]

# %%
###################################################################################

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=20)

# %%
kmeans.fit(df_exercises.drop(['splitName'],axis = 1))
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=20, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
df_exercises = df_exercises.reset_index(drop=True)
df_exercises['labels'] = kmeans.labels_

# %%
df_exercises
# Out:
#                            splitName  workload  metabolicWorkload  \
# 0                 Game-11v11 with se       1.0               16.5
# 1                            Session       2.2               36.0
# 2                               11v1       0.8               13.3
# 3                               11v1       0.6               14.2
# 4                 Game-11v11 with se       1.6               28.7
# 5                            Session       2.4               47.1
# 6                               11v1       0.4                8.7
# 7                            Session       2.0               31.5
# 8                 Game-11v11 with se       1.0               18.1
# 9                 Game-11v11 with se       1.0               20.4
# 10                           Session       2.1               43.4
# 11                              11v1       0.7               16.1
# 12                Game-11v11 with se       0.9               18.2
# 13                           Session       2.0               37.8
# 14                              11v1       0.7               14.7
# 15                           Session       2.1               35.5
# 16                Game-11v11 with se       1.4               22.9
# 17                Passing-drill dami       0.6                9.1
# 18                           Session       2.2               34.3
# 19                Game-11v11 with se       1.2               19.9
# 20                Game-11v11 with se       1.3               24.6
# 21                           Session       2.5               50.6
# 22                              11v1       1.1               21.6
# 23                           Session       2.6               49.5
# 24                Game-11v11 with se       1.4               29.5
# 25                Game-11v11 with se       1.1               20.9
# 26                              11v1       0.7               13.8
# 27                           Session       2.0               37.7
# 28                           Session       1.7               29.4
# 29                Game-11v11 with se       1.1               21.5
# ...                              ...       ...                ...
# 6269                      Game-11v11       0.9               15.4
# 6270                         Warm-up       0.3                4.5
# 6271                   Int-run 20 40       2.3               43.6
# 6272  Defensive-phase counter attack       1.5               27.5
# 6273                         Session       3.4               69.1
# 6274                      Game-11v11       0.7               12.1
# 6275  Defensive-phase counter attack       1.3               25.1
# 6276                      Game-11v11       1.1               21.0
# 6277  Defensive-phase counter attack       2.0               40.3
# 6278                         Session       4.7              109.7
# 6279  Defensive-phase counter attack       1.1               21.8
# 6280                         Session       2.9               61.6
# 6281  Defensive-phase counter attack       1.2               26.5
# 6282                      Game-11v11       0.8               13.9
# 6283                         Session       2.6               56.1
# 6284                      Game-11v11       1.0               18.4
# 6285                         Session       3.5               76.0
# 6286  Defensive-phase counter attack       1.4               22.4
# 6287                         Session       3.5               76.6
# 6288                         Warm-up       0.2                3.8
# 6289  Defensive-phase counter attack       1.2               25.7
# 6290                         Session       4.5              114.4
# 6291  Defensive-phase counter attack       2.2               37.1
# 6292                      Game-11v11       0.9               20.9
# 6293                         Session       3.9               89.7
# 6294                      Game-11v11       1.0               20.3
# 6295  Defensive-phase counter attack       1.4               29.7
# 6296  Defensive-phase counter attack       1.3               19.7
# 6297                      Game-11v11       0.8               14.7
# 6298                         Session       2.8               53.5
#
#       mechanicalWorkload  kinematicWorkload  labels
# 0                   24.3               16.1      16
# 1                   53.4               35.8       7
# 2                   20.5               14.3      16
# 3                    7.6               15.5      13
# 4                   40.2               21.6       0
# 5                   57.4               43.0       1
# 6                    9.5                7.5       3
# 7                   49.7               30.2       7
# 8                   27.3               15.0      16
# 9                   18.5               19.8      11
# 10                  40.1               40.0      15
# 11                   9.6               15.3      13
# 12                  21.7               14.7      16
# 13                  38.7               35.3      18
# 14                  10.7               14.3      13
# 15                  59.2               32.3       7
# 16                  36.3               18.8       0
# 17                  16.4                7.3       3
# 18                  58.1               35.5       7
# 19                  34.4               16.8       0
# 20                  32.3               21.5       0
# 21                  50.3               56.4       2
# 22                   8.6               31.0       6
# 23                  63.0               37.0       1
# 24                  33.5               17.6       0
# 25                  24.3               17.7      11
# 26                  12.9               12.2      13
# 27                  43.8               36.5      15
# 28                  35.8               38.9      18
# 29                  21.8               19.8      11
# ...                  ...                ...     ...
# 6269                19.9               16.7      16
# 6270                 6.1                5.2       3
# 6271                19.0               62.3       4
# 6272                26.9               35.0       6
# 6273                59.9               50.8       2
# 6274                17.8               11.8      16
# 6275                30.5               22.6      11
# 6276                25.1               18.4      11
# 6277                39.0               39.6      15
# 6278                71.4              114.3      10
# 6279                21.1               20.5      11
# 6280                44.6               61.8       2
# 6281                29.2               17.6      11
# 6282                18.4               12.9      16
# 6283                61.0               42.4       1
# 6284                26.3               13.1      16
# 6285                66.8               75.6      17
# 6286                36.6               22.6       0
# 6287                36.9               98.2      12
# 6288                 4.9                5.1       3
# 6289                17.5               25.8      11
# 6290                49.4              120.1      10
# 6291                28.7               59.8       4
# 6292                19.8               14.8      16
# 6293                79.2               62.8      19
# 6294                22.8               14.8      16
# 6295                27.6               26.1      11
# 6296                35.1               15.9       0
# 6297                19.3               14.1      16
# 6298                68.5               41.1       1
#
# [6299 rows x 6 columns]

# %%
df_exercises['splitName'] = df_exercises['splitName'].astype(str).str.lower()

# %%
drills = df_exercises['splitName'].unique()

# %%
drills
# Out:
# array(['game-11v11 with se', 'session', '11v1', 'passing-drill dami',
#        'functional-trainin', '4vs4-plus 2 or 4vs', '4vs4-plus 2 and 4v',
#        'third-game', 'second-game', 'fourth-game', 'preparation-to the',
#        'set-pieces', 'warm-up', '2nd-half', '1st-half',
#        'individualised-training', 'possession-10v10 conquer line',
#        'game-11v11', 'game', '1st.half', '2nd.half',
#        'defensive-phase counter attack', 'football-tennis', '11vs1',
#        '10v11', 'game-11vs11', 'first-half', 'second-half',
#        'warm-up pre match', '5v7-plus 1 per 2', '5v5-plus 3 per 2 2',
#        '5v5-plus 3 per 2 1', 'int-run 15 15 1', 'int-run 15 15 3',
#        'int-run 15 15 2', 'int-run 20 40 2', 'offensive-phase 11v1',
#        'second-possession', 'first-possession', 'possession-6 6vs6 ',
#        'defensive-phase co', 'second-game 9vs9', 'first-game 9vs9',
#        'possession-game 6v', 'first-intermittent', 'set-pieces defensive',
#        'offensive-combinat', '4vs6-last 20 m', 'defensive-line org',
#        'shifting-and ball ', 'shooting', 'shifting-10vs10',
#        'offensive-phase 11v1 plus 11v7', 'finalisation',
#        'cross-and finalisations', 'block-2', 'block-1', 'defensive-phase',
#        'finalisations', 'general-strength', 'offensive-phase 10v6',
#        '2nd-defensive phase 9v7', 'game-9v9', '1st-defensive phase 9v7',
#        'int-run 10 10 1', 'int-run 10 10 2', '11v10',
#        '10vs10-conquer lin', 'set-pieces defensi', 'trow-in',
#        'yo-yo-irt l2', '3rd-int run 20 40', '2nd-int run 20 40',
#        '10v11-plus-10v1', 'def-line 3v3 4v6 5v8', '6vs8',
#        'tournament-6vs6', '4vs6', 'defensive-on count', 'game-7vs7',
#        '1st-block possession 10v10', '2nd-block possession 10v10',
#        'int-run 20 40 1', 'offensive-phase 10v7 plus gk', 'int-run 5 15',
#        'offensive-phase 11v7', 'block-3', 'block-4', 'int-run 15 15',
#        '11v1-and set piece', 'defensive-phase 7 plus 1 v 8',
#        'offensive-phase 11', '11v1-and strength', '10v11-plus 10v1',
#        'int-run 10 30 50', 'cross-and finalizations',
#        'situational-cross and finalizations',
#        'anticipation-and free cover ball',
#        '3rd-11v11 build up plus negative transition',
#        '2nd-11v11 build up plus negative transition',
#        '1st-11v11 build up plus negative transition', '1st-int run 20 40',
#        'cross-and finalisa', '1st-part', '2nd-part', '3rd-part',
#        'finalisations-2', 'cross-and finaliza', 'role-specific dril',
#        'offensive-phase 11v20', 'offensive-phase 11v13',
#        'offensive-phase 11v5', 'defensive-phase shifting and build up',
#        'offensive-phase 11v17', 'offensive-phase 11v16',
#        'offensive-phase 11v2', 'offensive-phase 11v4',
#        'offensive-phase 11v18', 'offensive-phase 11v9',
#        'offensive-phase 11v6', 'offensive-phase 11v11',
#        'offensive-phase 11v14', 'offensive-phase 11v10',
#        'offensive-phase 11v3', 'finalizations', 'defensive-line',
#        'hand-ball', '3rd-block', '1st-block', 'defensive-phase 5v6',
#        'game-half pitch', 'aerobic-work', 'offensive-phase build up',
#        '5v5-plus gks', '6th-block', '2nd-block', '4th-block', '5th-block',
#        'offensive phase build up with opponents',
#        'defensive-phase 7 plus 1 vs 8',
#        '1st-block defensive phase 5v7 plus 1 per 2',
#        '2nd-block defensive phase 5v7 plus 1 per 2', '5v5-plus gk',
#        'build-up', 'game-position 4vs3', 'aerobic-circuit',
#        'int-run 20 40', 'possession-10v10 4 gates', 'fb-block 1',
#        'specific-intermitttent run', 'fb-block 2', 'cb-block 1',
#        'cm-block 1', 'block-2 10v11', 'block-1 10v11',
#        '5-plus 2 v 8 plus 1', 'attacking-defending on cross',
#        'set-pieces and gen', 'game-11v11 plus set pieces defensive',
#        'warm-up plus mov. ', '1vs1-2vs2 4vs4 4vs', 'first-aerobic work',
#        'first-half game', 'aerobic-work plus ', 'second-half-game',
#        'second-aerobic wor',
#        '2nd-11v11 build up plus negative tranistion',
#        'defensive-phase 7v8', 'role-specific drill', 'game-8v8 plus 1j',
#        'situational-cross and finalisations', 'game-11vs11 and se',
#        'possession-10v10 c', 'defensive-line 4vs', 'game-7v7',
#        '3rd-5v4 plus 4 per 2', '2nd-5v4 plus 4 per 2',
#        '1st-int-run 20 40', '1st-5v4 plus 4 per 2', 'core-and set piece',
#        'tactic-warm up', 'theme-game 10vs10 ', 'second-half game',
#        'possession-10vs10 ', '11v442', 'game-66m', 'second-intermitten',
#        'passing-drill damiano', 'boxes-and set piec', '1st-work',
#        '11v1-plus sprint', 'damiano-2 version', 'extra-time',
#        '2nd-defensive phase 5v4 plus 5j',
#        '3rd-defensive phase 5v4 plus 5j', 'int-run 20 20',
#        '1st-defensive phase 5v4 plus 5j', 'defensive-phase 2',
#        'intermittent-run-2', 'defensive-phase 1', 'run-1',
#        'defensive-phase 3', 'sixth-game', '4vs4-4 share', 'fiveth-game',
#        'passing-drill romb', '4v4-and-4 share',
#        'defensive-phase 5v6 on counter attack', 'functional-passing',
#        '7v7-and intermitte', '7v7plus7', 'preparation-to-the',
#        'offensive-phase 7v6 1', '5v5-plus 1j 2',
#        'offensive-phase 9v7 plus 5v2', 'offensive-phase 7v6 2',
#        'offensive-phase 9v7 plus 5v2 ', 'defensive-line 5v7', '11v0',
#        'intermittent-run 2', 'cross-and finalisation',
#        'defensive elastic', '1st', '2nd', '5th', 'position-game 4v4 ',
#        '20-10 m alattacid ', '11vs-1 set pieces ',
#        'defensive-phase 7v8 others', 'defensive-phase 7v8 defenders',
#        'cross and finalizations and set pieces', 'possession-10v10',
#        'position game 2x(4v4+2j) + 2x(4v4+3j)',
#        'block-3 defensive phase 5v5 plus 2j situational',
#        'block-2 defensive phase 5v5 plus 2j situational',
#        'block-1 defensive phase 5v5 plus 2j situational', 'int-run 10 10',
#        '1st-11v11 build up', '2nd-11v11 build up', '3rd-11v11 build up',
#        'agility'], dtype=object)

# %%
columns = ['splitName']
for cluster in range(len(kmeans.cluster_centers_)):
    columns.append('cluster' + str(cluster + 1))

# %%
columns
# Out:
# ['splitName',
#  'cluster1',
#  'cluster2',
#  'cluster3',
#  'cluster4',
#  'cluster5',
#  'cluster6',
#  'cluster7',
#  'cluster8',
#  'cluster9',
#  'cluster10',
#  'cluster11',
#  'cluster12',
#  'cluster13',
#  'cluster14',
#  'cluster15',
#  'cluster16',
#  'cluster17',
#  'cluster18',
#  'cluster19',
#  'cluster20']

# %%
df_normalized = pd.DataFrame()

for drill in drills:
    df_specific_drill = df_exercises.loc[df_exercises['splitName'].isin([drill])]
    df_value_counts = pd.DataFrame(df_specific_drill['labels'].value_counts(normalize=True))
    
    new_row = []
    
    for i in range(len(columns[1:])):
        try:
            new_row.append(df_value_counts.loc[i]['labels'])
        except:
            new_row.append(0)
    
    new_row.insert(0, drill)            
    new_row = pd.Series(new_row)

    df_normalized = df_normalized.append(new_row, ignore_index=True)

# %%
df_normalized.columns = columns

# %%
df_normalized = df_normalized.sort_values('splitName').reset_index(drop=True)

# %%
df_normalized
# Out:
#                                        splitName  cluster1  cluster2  \
# 0                                          10v11  0.091429  0.002857
# 1                                10v11-plus 10v1  0.071429  0.000000
# 2                                10v11-plus-10v1  0.062500  0.000000
# 3                             10vs10-conquer lin  0.000000  0.000000
# 4                                           11v0  0.100000  0.000000
# 5                                           11v1  0.000000  0.000000
# 6                             11v1-and set piece  0.166667  0.000000
# 7                              11v1-and strength  0.000000  0.000000
# 8                               11v1-plus sprint  0.000000  0.000000
# 9                                          11v10  0.111111  0.000000
# 10                                        11v442  0.032258  0.000000
# 11                            11vs-1 set pieces   0.214286  0.000000
# 12                                         11vs1  0.000000  0.000000
# 13                                           1st  0.000000  0.000000
# 14                            1st-11v11 build up  0.000000  0.000000
# 15   1st-11v11 build up plus negative transition  0.000000  0.000000
# 16                          1st-5v4 plus 4 per 2  0.000000  0.000000
# 17                                     1st-block  0.416667  0.000000
# 18    1st-block defensive phase 5v7 plus 1 per 2  0.000000  0.000000
# 19                    1st-block possession 10v10  0.000000  0.000000
# 20               1st-defensive phase 5v4 plus 5j  0.000000  0.000000
# 21                       1st-defensive phase 9v7  0.000000  0.000000
# 22                                      1st-half  0.000000  0.000000
# 23                             1st-int run 20 40  0.000000  0.000000
# 24                             1st-int-run 20 40  0.000000  0.000000
# 25                                      1st-part  0.000000  0.000000
# 26                                      1st-work  0.000000  0.000000
# 27                                      1st.half  0.006993  0.062937
# 28                            1vs1-2vs2 4vs4 4vs  0.000000  0.000000
# 29                            20-10 m alattacid   0.000000  0.000000
# ..                                           ...       ...       ...
# 211                                        run-1  0.000000  0.000000
# 212                           second-aerobic wor  0.000000  0.000000
# 213                                  second-game  0.000000  0.000000
# 214                             second-game 9vs9  0.000000  0.000000
# 215                                  second-half  0.000000  0.000000
# 216                             second-half game  0.000000  0.000000
# 217                             second-half-game  0.000000  0.000000
# 218                           second-intermitten  0.000000  0.000000
# 219                            second-possession  0.000000  0.000000
# 220                                      session  0.108574  0.041667
# 221                                   set-pieces  0.068493  0.000000
# 222                           set-pieces and gen  0.000000  0.000000
# 223                           set-pieces defensi  0.000000  0.000000
# 224                         set-pieces defensive  0.062500  0.000000
# 225                              shifting-10vs10  0.178571  0.000000
# 226                           shifting-and ball   1.000000  0.000000
# 227                                     shooting  0.000000  0.000000
# 228          situational-cross and finalisations  0.000000  0.000000
# 229          situational-cross and finalizations  0.000000  0.000000
# 230                                   sixth-game  0.000000  0.000000
# 231                   specific-intermitttent run  0.000000  0.000000
# 232                               tactic-warm up  0.000000  0.000000
# 233                           theme-game 10vs10   0.000000  0.000000
# 234                                   third-game  0.000000  0.000000
# 235                              tournament-6vs6  0.000000  0.000000
# 236                                      trow-in  0.000000  0.000000
# 237                                      warm-up  0.021739  0.000000
# 238                           warm-up plus mov.   0.000000  0.000000
# 239                            warm-up pre match  0.000000  0.000000
# 240                                 yo-yo-irt l2  1.000000  0.000000
#
#      cluster3  cluster4  cluster5  cluster6  cluster7  cluster8  cluster9  \
# 0    0.002857  0.062857  0.008571   0.00000  0.054286  0.005714  0.000000
# 230   0.000000   0.000000   0.000000   0.000000   0.000000
# 231   0.000000   0.000000   0.000000   0.000000   0.000000
# 232   0.000000   0.000000   0.000000   0.000000   0.000000
# 233   0.000000   0.400000   0.000000   0.000000   0.000000
# 234   0.000000   0.000000   0.000000   0.000000   0.000000
# 235   0.000000   0.750000   0.000000   0.000000   0.000000
# 236   0.000000   0.000000   0.000000   0.000000   0.000000
# 237   0.000000   0.065217   0.000000   0.000000   0.000000
# 238   0.000000   0.111111   0.000000   0.000000   0.000000
# 239   0.000000   0.000000   0.000000   0.000000   0.000000
# 240   0.000000   0.000000   0.000000   0.000000   0.000000
#
# [241 rows x 21 columns]

# %%
clusters = {}

for cluster in columns[1:]:
    clusters.update({cluster: []})

# %%
clusters
# Out:
# {'cluster1': [],
#  'cluster2': [],
#  'cluster3': [],
#  'cluster4': [],
#  'cluster5': [],
#  'cluster6': [],
#  'cluster7': [],
#  'cluster8': [],
#  'cluster9': [],
#  'cluster10': [],
#  'cluster11': [],
#  'cluster12': [],
#  'cluster13': [],
#  'cluster14': [],
#  'cluster15': [],
#  'cluster16': [],
#  'cluster17': [],
#  'cluster18': [],
#  'cluster19': [],
#  'cluster20': []}

# %%
i = 0

for drill in drills:
    df_specific_drill = df_normalized.loc[df_normalized['splitName'].isin([drill])].drop(['splitName'],axis = 1)

    max_value = df_specific_drill.max(axis=1).values[0]
    max_value_key = df_specific_drill.idxmax(axis=1).values[0]

    if max_value >= 0.75:
        clusters[max_value_key].append(drill)
        
        i += 1

print(len(drills), i)
# Out:
# 241 120

# %%
clusters
# Out:
# {'cluster1': ['shifting-and ball ',
#   'yo-yo-irt l2',
#   '4v4-and-4 share',
#   'position game 2x(4v4+2j) + 2x(4v4+3j)'],
#  'cluster2': [],
#  'cluster3': [],
#  'cluster4': ['4vs4-plus 2 or 4vs',
#   '4vs4-plus 2 and 4v',
#   'third-game',
#   'second-game',
#   'fourth-game',
#   'warm-up',
#   'football-tennis',
#   'warm-up pre match',
#   '5v7-plus 1 per 2',
#   '5v5-plus 3 per 2 2',
#   '5v5-plus 3 per 2 1',
#   'first-possession',
#   'second-game 9vs9',
#   'first-game 9vs9',
#   'possession-game 6v',
#   '4vs6-last 20 m',
#   'shooting',
#   'finalisations',
#   'general-strength',
#   '1st-defensive phase 9v7',
#   'set-pieces defensi',
#   'trow-in',
#   '4vs6',
#   '1st-block possession 10v10',
#   '2nd-block possession 10v10',
#   'anticipation-and free cover ball',
#   '3rd-11v11 build up plus negative transition',
#   '2nd-11v11 build up plus negative transition',
#   '2nd-part',
#   'finalisations-2',
#   'offensive-phase 11v20',
#   'defensive-phase shifting and build up',
#   'offensive-phase 11v18',
#   'offensive-phase 11v6',
#   'offensive-phase 11v14',
#   'offensive-phase 11v3',
#   'hand-ball',
#   '6th-block',
#   '2nd-block',
#   '4th-block',
#   '5th-block',
#   '1st-block defensive phase 5v7 plus 1 per 2',
#   '5v5-plus gk',
#   'cm-block 1',
#   'block-2 10v11',
#   'block-1 10v11',
#   'set-pieces and gen',
#   'warm-up plus mov. ',
#   'first-half game',
#   'second-half-game',
#   'role-specific drill',
#   'game-11vs11 and se',
#   '3rd-5v4 plus 4 per 2',
#   '2nd-5v4 plus 4 per 2',
#   '1st-5v4 plus 4 per 2',
#   'core-and set piece',
#   'tactic-warm up',
#   'second-half game',
#   'second-intermitten',
#   'boxes-and set piec',
#   'damiano-2 version',
#   '2nd-defensive phase 5v4 plus 5j',
#   '3rd-defensive phase 5v4 plus 5j',
#   '1st-defensive phase 5v4 plus 5j',
#   'defensive-phase 2',
#   'defensive-phase 1',
#   'defensive-phase 3',
#   'sixth-game',
#   'fiveth-game',
#   'passing-drill romb',
#   '7v7plus7',
#   'offensive-phase 7v6 1',
#   '5v5-plus 1j 2',
#   'offensive-phase 9v7 plus 5v2 ',
#   '1st',
#   '2nd',
#   '5th',
#   '20-10 m alattacid ',
#   'block-3 defensive phase 5v5 plus 2j situational',
#   'block-2 defensive phase 5v5 plus 2j situational',
#   'block-1 defensive phase 5v5 plus 2j situational',
#   '2nd-11v11 build up',
#   '3rd-11v11 build up',
#   'agility'],
#  'cluster5': ['int-run 10 30 50',
#   'offensive-phase 11v17',
#   'intermittent-run 2'],
#  'cluster6': [],
#  'cluster7': ['int-run 10 10 2',
#   'offensive-phase 11v5',
#   'offensive-phase 11v16',
#   'offensive-phase 11v9'],
#  'cluster8': [],
#  'cluster9': [],
#  'cluster10': [],
#  'cluster11': [],
#  'cluster12': [],
#  'cluster13': [],
#  'cluster14': ['int-run 15 15 1',
#   'int-run 15 15 3',
#   'int-run 15 15 2',
#   'int-run 20 40 2',
#   'finalisation',
#   'offensive-phase 11v13',
#   'fb-block 1',
#   'fb-block 2',
#   'first-aerobic work',
#   'second-aerobic wor',
#   '1st-int-run 20 40',
#   'int-run 20 20',
#   'intermittent-run-2',
#   'run-1',
#   'int-run 10 10'],
#  'cluster15': [],
#  'cluster16': [],
#  'cluster17': ['defensive-line org',
#   '10vs10-conquer lin',
#   'tournament-6vs6',
#   'game-7vs7',
#   'offensive-phase 11v2',
#   'position-game 4v4 ',
#   'cross and finalizations and set pieces'],
#  'cluster18': [],
#  'cluster19': ['offensive-phase 11v4',
#   'offensive-phase 11v10',
#   '7v7-and intermitte'],
#  'cluster20': []}

# %%
#df_normalized.loc[df_normalized['splitName'].isin(['warm-up'])].max(axis=1)

# %%
#############################################################################

# %%
from matplotlib import style
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
style.use("ggplot")

columns = ['workload', 'metabolicWorkload', 'mechanicalWorkload', 'kinematicWorkloadvar']

# %%
X = df_exercises.drop(['splitName'],axis = 1).values

labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

n_clusters_ = len(np.unique(labels))

colors = 10*['r','g','b','c','k','y','m']
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(len(X)):
    ax.scatter(X[i][0], X[i][1], X[i][2], c=colors[labels[i]], marker='o')

ax.scatter(cluster_centers[:,0],cluster_centers[:,1],cluster_centers[:,2],
            marker="x",color='k', s=150, linewidths = 5, zorder=10)

plt.show()
